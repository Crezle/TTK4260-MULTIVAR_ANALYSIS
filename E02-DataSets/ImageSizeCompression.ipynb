# %% [markdown]
# # Image compression

# %%
# Modules
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
# %matplotlib inline
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Read the image
plt.figure(figsize=(10,10))
img = imread('./data/salami.jpg')
plt.rcParams["axes.grid"] = False
plt.imshow(img)

# %%
img.size
# Out:
# 470448

# %%
img_size = img.shape
print("Shape of the image is ",img_size)
# Out:
# Shape of the image is  (396, 396, 3)

# %%
print("%d bytes" % (img.size * img.itemsize))
# Out:
# 470448 bytes

# %% [markdown]
# # File compression and image segemntation
# TASK
# * How do we reduce the file size ?
# * How do we segment the image ?
